# %% [markdown]
# ## Clustering

# %%
import os
import sys

# adding classes folder to system path
sys.path.insert(0, os.path.abspath('..') + '/classes')

from clustering import Clustering
obj = Clustering()

# %% [markdown]
# ### Fit a vectorizer using data
# The vectorizer can be changed as a parameter. We can use either `tfidf` or `tf` for fitting a vectorizer that will be used in the next steps for tweet clustering. Example of changing the vectorizer:
# `obj.params["vectorizer"] = "tfidf"`

# %%
fitted_vectorizer, vectorizer = obj.fit_vectorizer()

# %% [markdown]
# ### Finding the number of topics

# %%
obj.find_optimal_kelbow(fitted_vectorizer)

# %%
obj.fit_kmeans(fitted_vectorizer, vectorizer)
# Out:
# Fitting clustering algorithm using: tfidf
# Top terms per cluster:
# Cluster 0:['جمهوری', 'اسلامی', 'دارد', 'استاندار', 'اضطراری', 'زمین', 'حمایت', 'شیوع', 'پاسخ', 'آجیم', 'کاری', 'خونین', 'شماری', 'نایاک', 'اهوازی']
# Cluster 1:['میرم', 'صد', 'میشم', 'برنگردم', 'ریت', 'دونم', 'بد', 'متاسفانه', 'شیاد', 'دستاورد', 'اظهارات', 'لمیز', 'بخیر', 'تموم', 'نتونم']
# Cluster 2:['ایران', 'قرنطینه', 'روحانی', 'خانگی', 'مقابله', 'آمار', 'آمریکا', 'ایتالیا', 'قوی', 'وارد', 'نماینده', 'نداریم', 'امکانات', 'مردم', 'کاغذی']
# Cluster 3:['بمانیم', 'خانه', 'سفارش', 'درخانه', 'جدی', 'مایحتاج', 'اخلاقی', 'بیمارستان', 'بمانید', 'افزایش', 'خونه', 'دهیم', 'ندارد', 'مشهد', 'دوران']
# Cluster 4:['ایران', 'ویروس', 'مردم', 'شیوع', 'مقابله', 'مبتلا', 'کنیم', 'قرنطینه', 'بیماری', 'آمار', 'بحران', 'کار', 'آمریکا', 'درمان', 'بیمارستان']
# Cluster 5:['ویروس', 'جدی', 'مبتلا', 'افغانستان', 'شیوع', 'اعلام', 'بهداشت', 'مبتلایان', 'ایران', 'شمار', 'وزارت', 'مردم', 'گذشته', 'خامنه', 'مقابله']
# ...
